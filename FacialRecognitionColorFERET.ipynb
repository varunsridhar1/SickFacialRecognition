# %%
from PIL import Image
from facenet_pytorch import MTCNN
import io
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
im1 = Image.open('ExampleImage/00001_930831_fa_a.ppm')
plt.imshow(im1)
plt.axis('off')
im1.close()

# %%
im2 = Image.open('ExampleImage/00001_930831_fb_a.ppm')
plt.imshow(im2)
plt.axis('off')
im2.close()

# %%
im3 = Image.open('ExampleImage/00001_930831_hl_a.ppm')
plt.imshow(im3)
plt.axis('off')
im3.close()

# %%
im4 = Image.open('ExampleImage/00001_930831_hr_a.ppm')
plt.imshow(im4)
plt.axis('off')
im4.close()

# %%
im5 = Image.open('ExampleImage/00001_930831_pr_a.ppm')
plt.imshow(im5)
plt.axis('off')
im5.close()

# %%
mtcnn = MTCNN(select_largest=False, post_process=False)
im1 = Image.open('ExampleImage/00001_930831_fa_a.ppm')
img_cropped = mtcnn(im1)
img_cropped.shape
# Out:
# torch.Size([3, 160, 160])

# %%
plt.imshow(img_cropped.permute(1, 2, 0).int().numpy())
plt.axis('off')
im1.close()
